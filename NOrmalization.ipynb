# %% [markdown]
# # normalization practice

# %% [markdown]
# # What is Normalization?
# Normalization is a technique in feature scaling where you rescale numerical data into a fixed range, usually 0 to 1.
# # Why Normalization is Needed in Machine Learning?
# Because:
#
# Different features may have different scales (e.g., Age: 18–60, Salary: 10k–100k)
#
# Many ML algorithms (like KNN, SVM, Gradient Descent) work better when features are on similar scales
#
# Prevents one large feature from dominating the others

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# simple code
# Sample dataset
data = {
    'Age': [18, 25, 35, 45, 55],
    'Salary': [15000, 25000, 35000, 45000, 55000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Age  Salary
# 0   18   15000
# 1   25   25000
# 2   35   35000
# 3   45   45000
# 4   55   55000

# %%
from sklearn.preprocessing import MinMaxScaler

# Create scaler object
scaler = MinMaxScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df)

# Convert back to DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=df.columns)

print(scaled_df)
# Out:
#         Age  Salary
# 0  0.000000    0.00
# 1  0.189189    0.25
# 2  0.459459    0.50
# 3  0.729730    0.75
# 4  1.000000    1.00

# %% [markdown]
# # Example with Output Column
# 👇 Sample Dataset:

# %%
# sample datasets

data = {
    'Age': [18, 25, 35, 45, 55],
    'Salary': [15000, 25000, 35000, 45000, 55000],
    'Purchased': [0, 1, 0, 1, 0]   # Target/output column
}

df = pd.DataFrame(data)

# %%
from sklearn.preprocessing import MinMaxScaler

# Step 1: Separate input (X) and output (y)
X = df[['Age', 'Salary']]          # Features
y = df['Purchased']                # Target/output

# Step 2: Apply MinMaxScaler only on X
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Convert scaled data back to DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Step 4: Combine back if needed
final_df = pd.concat([X_scaled_df, y], axis=1)

print(final_df)
# Out:
#         Age  Salary  Purchased
# 0  0.000000    0.00          0
# 1  0.189189    0.25          1
# 2  0.459459    0.50          0
# 3  0.729730    0.75          1
# 4  1.000000    1.00          0

# %% [markdown]
# # csve file

# %%
df=pd.read_csv('/content/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df=df[['Glucose','BloodPressure','SkinThickness','Insulin','Outcome']]

# %%
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin  Outcome
# 0        148             72             35        0        1
# 1         85             66             29        0        0
# 2        183             64              0        0        1
# 3         89             66             23       94        0
# 4        137             40             35      168        1
# ..       ...            ...            ...      ...      ...
# 763      101             76             48      180        0
# 764      122             70             27        0        0
# 765      121             72             23      112        0
# 766      126             60              0        0        1
# 767       93             70             31        0        0
#
# [768 rows x 5 columns]

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin
# 60        84              0              0        0
# 618      112             82             24        0
# 346      139             46             19       83
# 294      161             50              0        0
# 231      134             80             37      370
# ..       ...            ...            ...      ...
# 71       139             64             35      140
# 106       96            122              0        0
# 270      101             86             37        0
# 435      141              0              0        0
# 102      125             96              0        0
#
# [614 rows x 4 columns]

# %%
y_train
# Out:
# 60     0
# 618    1
# 346    0
# 294    0
# 231    1
#       ..
# 71     0
# 106    0
# 270    1
# 435    1
# 102    0
# Name: Outcome, Length: 614, dtype: int64

# %% [markdown]
# # *** **Feature-Scaling:NOrmalization:minmax scaler

# %%
x_train_scalled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_
#        [0.75879397, 0.57377049, 0.63492063, 0.32033097],
#        [0.54773869, 0.49180328, 0.12698413, 0.21513002],
#        [0.68341709, 0.68852459, 0.55555556, 0.1536643 ],
#        [0.90954774, 0.63934426, 0.66666667, 0.3463357 ],
#        [0.51256281, 0.60655738, 0.        , 0.        ],
#        [0.60301508, 0.70491803, 0.        , 0.        ],
#        [0.79396985, 0.93442623, 0.        , 0.        ],
#        [0.75376884, 0.63934426, 0.46031746, 0.14893617],
#        [0.34170854, 0.50819672, 0.20634921, 0.0177305 ],
#        [0.56281407, 0.54098361, 0.34920635, 0.        ],
#        [0.45226131, 0.49180328, 0.        , 0.        ],
#        [0.69849246, 0.6147541 , 0.        , 0.        ],
#        [0.69849246, 0.50819672, 0.65079365, 0.56737589],
#        [0.46733668, 0.49180328, 0.        , 0.        ],
#        [0.42211055, 0.60655738, 0.49206349, 0.        ],
#        [0.42713568, 0.60655738, 0.34920635, 0.        ],
#        [0.36683417, 0.40983607, 0.15873016, 0.        ],
#        [0.56281407, 0.63934426, 0.63492063, 0.        ],
#        [0.82914573, 0.72131148, 0.        , 0.        ],
#        [0.38693467, 0.45901639, 0.47619048, 0.06619385],
#        [0.47738693, 0.59016393, 0.        , 0.        ],
#        [0.73366834, 0.57377049, 0.6031746 , 0.42553191],
#        [0.3718593 , 0.57377049, 0.63492063, 0.05791962]])

# %%
x_train_scalled=pd.DataFrame(data=x_train_scalled,columns=x_train.columns)
x_test_scalled=pd.DataFrame(data=x_test_scalled,columns=x_test.columns)

# %%
x_train_scalled
# Out:
#       Glucose  BloodPressure  SkinThickness   Insulin
# 0    0.422111       0.000000       0.000000  0.000000
# 1    0.562814       0.672131       0.380952  0.000000
# 2    0.698492       0.377049       0.301587  0.098109
# 3    0.809045       0.409836       0.000000  0.000000
# 4    0.673367       0.655738       0.587302  0.437352
# ..        ...            ...            ...       ...
# 609  0.698492       0.524590       0.555556  0.165485
# 610  0.482412       1.000000       0.000000  0.000000
# 611  0.507538       0.704918       0.587302  0.000000
# 612  0.708543       0.000000       0.000000  0.000000
# 613  0.628141       0.786885       0.000000  0.000000
#
# [614 rows x 4 columns]

# %%
x_test_scalled
# Out:
#       Glucose  BloodPressure  SkinThickness   Insulin
# 0    0.492462       0.475410       0.523810  0.224586
# 1    0.562814       0.614754       0.507937  0.000000
# 2    0.542714       0.524590       0.000000  0.000000
# 3    0.537688       0.655738       0.000000  0.000000
# 4    0.683417       0.737705       0.000000  0.000000
# ..        ...            ...            ...       ...
# 149  0.829146       0.721311       0.000000  0.000000
# 150  0.386935       0.459016       0.476190  0.066194
# 151  0.477387       0.590164       0.000000  0.000000
# 152  0.733668       0.573770       0.603175  0.425532
# 153  0.371859       0.573770       0.634921  0.057920
#
# [154 rows x 4 columns]
